# %%
import os
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist
from heapq import nlargest
# Out:
# /Users/viviando/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/viviando/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /var/folders/b8/4ntn3_wd1wg59r0lmbfgfmwc0000gn/T/ipykernel_46854/3682295668.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
os.chdir('/Users/viviando/Desktop/MSADS/ads599_capstone/climate-lang-processing')
df = pd.read_csv('data/news_cleaned.csv')

# %%
sample_df = df.sample(50)

# %% [markdown]
# ### Extractive summarization, where an exact sentence (determined to be the most important) from the text is extracted to be the summary.

# %%
def summarize_text(text):
    # Tokenize sentences
    sentences = sent_tokenize(text)

    # Tokenize words
    words = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word.lower() for word in words if word.isalnum() and word.lower() not in stop_words]

    # Calculate word frequency
    word_freq = FreqDist(words)

    # Calculate sentence scores based on word frequency
    sentence_scores = {}
    for sentence in sentences:
        for word in word_tokenize(sentence.lower()):
            if word in word_freq:
                if sentence not in sentence_scores:
                    sentence_scores[sentence] = word_freq[word]
                else:
                    sentence_scores[sentence] += word_freq[word]

    # Select top 30% sentences with highest scores as summary
    summary_sentences = nlargest(int(0.3*len(sentences)), sentence_scores, key=sentence_scores.get)
    summary = ' '.join(summary_sentences)

    return summary

# Apply summarization function to each snippet in the DataFrame
sample_df['summary'] = sample_df['snippet'].apply(summarize_text)

# Display the original snippet and its summary
for index, row in sample_df.iterrows():
    print("Original Text:")
    print(row['snippet'])
    print("\nSummary:")
    print(row['summary'])
    print("\n")
# Out:
# Original Text:
# wrong. i have to go because wayne has agreed with juan in two of the three blocks so far, we're going to have to leave it there. my head is spinning. thanks to michelle fields and juan williams for joining us this week. coming up snowed in and sick of it. hey, global warming crowd, i got
#
# Summary:
# i have to go because wayne has agreed with juan in two of the three blocks so far, we're going to have to leave it there.
#
#
# Original Text:
# and i followed grimm's response to hurricane sandy and traced his trajectory on the issue of climate change and something amazing happened over the course of our time with him. republican michael grimm went from being a climate change denialist, someone who rejected
#
# Summary:
#
#
#
# Original Text:
# that climate change exists than a blizzard that it doesn't. unless a blizzard hits miami. we have a panel of experts to help us understand the science and consequences of climate change and yes, ideas to break the political paralysis over it. kate marvel is a scientist at
#
# Summary:
# we have a panel of experts to help us understand the science and consequences of climate change and yes, ideas to break the political paralysis over it.
#
#
# Original Text:
# it is up on the high plains of the country. as you can see, it is hot and it is dry, and according to the un this whole region is among the most vulnerable to climate change in the world. but the people here have been
#
# Summary:
#
#
#
# Original Text:
# sense that we are facing a crisis. if you look at the intergovernmental plan on climate change, a report on climate change, it let's us know that we are at a tipping point. that within the decade or so that we are going to experience irreversible tag to the planet. so something has to happen.
#
# Summary:
# if you look at the intergovernmental plan on climate change, a report on climate change, it let's us know that we are at a tipping point.
#
#
# Original Text:
# of congress, a difficult one. someone should tell her that if you want to be taken seriously even as the youngest member of the house, protesting outside the former speaker's office isn't a genius move. she appeared with 200 young climate change activists and it
#
# Summary:
#
#
#
# Original Text:
# opportunity to solve the climate crisis. the world's major powers came within several signatures of endorsing a binding global framework to reduce carbon emissions far closer than we have come since. you go on to write about the conditions of success.
#
# Summary:
#
#
#
# Original Text:
# politics of congress. just before i let you go, the lead story, this executive order changing the us policy on climate change affecting the coal and gas embers billy mcclure energies, it is generating a
#
# Summary:
#
#
#
# Original Text:
# pipeline if it could droibt climate change. something his own state department concluded would not occur, not surprisingly, though, the president sided with his own party. here's what he had to say. america's now a global leader when it comes to taking serious action to fight climate change.
#
# Summary:
# america's now a global leader when it comes to taking serious action to fight climate change.
#
#
# Original Text:
# for example, in the rest of the world where global warming is a huge issue. a great point. what is the rest of the world saying about the united states? we sit here in denial. our lawmakers do. oh, by the way, what ever happened to cap and trade?
#
# Summary:
# for example, in the rest of the world where global warming is a huge issue.
#
#
# Original Text:
# is disappearing. around 300000 people live around its waters, many make their living by fishing in it. but now dam and irrigation projects in neighbouring ethiopia combined with climate change could see it reduced to a small pool of water. the bbc's nancy kacungira has been
#
# Summary:
# but now dam and irrigation projects in neighbouring ethiopia combined with climate change could see it reduced to a small pool of water.
#
#
# Original Text:
# the switch can be both on and off. this supercharges any computer programme, making impossible problems easy to solve. we could find answers to climate change, make rapid progress in artificial intelligence and break encryption - secure codes            _
#
# Summary:
#
#
#
# Original Text:
# oppose that idea, though. the conference is in the suburbs of paris. while there, president obama has taken the opportunity to talk not just climate change, but the terrorist attacks that killed 130 people on friday the 13th.
#
# Summary:
#
#
#
# Original Text:
# line of the night. it was disingenuine. when he was gofrp vernor, he accepted climate change, he was enlightened on the subject. i think it's another example of the way he has pandered, the way he's changed his views or his
#
# Summary:
# i think it's another example of the way he has pandered, the way he's changed his views or his
#
#
# Original Text:
# senate on record saying climate change is real. it is not a hoax. that measure passed by a 98-1 margin. senators voted down a pair of amendments to the bill saying human activity is part of it.
#
# Summary:
# senators voted down a pair of amendments to the bill saying human activity is part of it.
#
#
# Original Text:
# to think on these issues. very disturbing and parental rights are absolutely left out of the picture. pete: we see it more and more, california is being criticized for allowing transgender issues to be taught in the classroom. right. pete: new york school board wants to climate change
#
# Summary:
# pete: we see it more and more, california is being criticized for allowing transgender issues to be taught in the classroom.
#
#
# Original Text:
# from companies like royal dutch shell. global investors have asked for commitments to reach carbon neutrality by 2050. altering the course of the climate crisis presents itself
#
# Summary:
#
#
#
# Original Text:
# pentagon, would you? no, i think that the department of defence was under very strict political supervision from the 0bama white house and that they were told to make sure that climate change is involved in all of your thinking about defence, so no, i do not
#
# Summary:
#
#
#
# Original Text:
# prop up your only ally, is leadership, then we have got a different definition. leadership. my definition of leadership would be leading on climate change and international accord potential in paris.
#
# Summary:
#
#
#
# Original Text:
# will continue to participate in climate change meetings until the withdrawal process is completed. an oxford university employee, who's been on the run on suspicion of murder, has been arrested with his alleged accomplice. andrew warren and professor wyndham
#
# Summary:
#
#
#
# Original Text:
# billionaire tom stier has pledged $100 million for any lawmaker who is going to make climate change one of his or her campaign processes, campaign ideologies, thoughts going forward. so 96 of them, or whatever, all
#
# Summary:
#
#
#
# Original Text:
# chance that the scepticism about climate change that we heard from trump in the white house is going to galvanise people want to do more, to ta ke take on more of the button because its not having to limit happening at
#
# Summary:
#
#
#
# Original Text:
# great industrialized nations, and he seems to relate this to be the odd man out on a lot of issues whether it's trade. whether it's iran, whether it's climate change. also now about reassured mitting russia, and i think in fact some
#
# Summary:
#
#
#
# Original Text:
# in the antarctic the size of delaware that is detaching. climate change is happening. the physics, mother nature is going to do what she's going to do whether trump stays in the paris climate deal or not and i think they get that this is a
#
# Summary:
#
#
#
# Original Text:
# to an extent. let's not forget this guy has held office in delaware for 30 years, probably shaken every single hand in that state. democrats will probably try to present him as having gone to the right a bit on abortion rights, climate change in his
#
# Summary:
#
#
#
# Original Text:
# this great american experience. exactly. i don't even call climate change tis climate crisis. the old ways are no longer relevant. the scientists tell us we have 12 years before there is irrepairable damage to the
#
# Summary:
# i don't even call climate change tis climate crisis.
#
#
# Original Text:
# and fuel trucks. and cut their greenhouse gas emissions in half. algae. its potential just keeps growing. its potential just keeps growing. performance comes in lots of flavors.  (dramatic orchestra)
#
# Summary:
# its potential just keeps growing. and cut their greenhouse gas emissions in half.
#
#
# Original Text:
# trade that drives the relationship. when it comes to climate change or getting north korea to contain its nuclear ambitions, america needs china onside. with a closer look at this meeting of the two presidents and really
#
# Summary:
#
#
#
# Original Text:
# that's stephen colbert breaking down climate change. why is the most liberal city in the nation arresting so many people for smoking pot? that's straight ahead. woman: this is not exactly what i expected. man: definitely more murdery than the reviews said.
#
# Summary:
# why is the most liberal city in the nation arresting so many people for smoking pot?
#
#
# Original Text:
# democratic voters tell us are the most important. they have climate change as number one. number two, 75% say medicare for all. as a pragmatic idealist, you do not support the version of medicare for all which would
#
# Summary:
# number two, 75% say medicare for all.
#
#
# Original Text:
# epa administrator scott pruitt is forced to resign amid pressure from lawmakers and the sheer embarrassment factor of moments like this one. we deserve to have something about at the epa who does protect our environment, someone who believes in climate change
#
# Summary:
#
#
#
# Original Text:
# all of which made me want to know, are there other approaches and are there other strategies we might pursue? in that spirit and in the wake of the copenhagen spirit here is a fascinating conversation and a fascinating set of ideas, concrete ideas to solve the problem of global warming and
#
# Summary:
#
#
#
# Original Text:
# climate change. it's a threat to our future. to the future of my 7-month-old daughter. that has a lot to do with why i got in the campaign. i want to make her proud and know i did everything i can to
#
# Summary:
# i want to make her proud and know i did everything i can to
#
#
# Original Text:
# he got a state visit. the last time that we had a donald trump state visit it cost £80 million in policing costs and we should not be rolling out the red carpet and spending that kind of money for somebody whose views you have just heard, around climate change and
#
# Summary:
#
#
#
# Original Text:
# defiance is in our bones. defiance never grows old. citracal maximum. calcium citrate plus d. highly soluble, easily absorbed. climate change has become a partisan issue.
#
# Summary:
# calcium citrate plus d. highly soluble, easily absorbed.
#
#
# Original Text:
# about donald trump. do you see a trump presidency undoing all the progress that the u.s. has made in the last ten years in the fight against climate change? he has said some things on the climate crisis that i think
#
# Summary:
#
#
#
# Original Text:
# documentary. a controversial one at that, on global warming, after this. you never considered making turn-by-turn navigation standard. if you want to talk about it. call me when you get there. that is if you find there, since you don't have
#
# Summary:
# you never considered making turn-by-turn navigation standard.
#
#
# Original Text:
# if they go what he called 'off limits.' thousands of climate change activists have begun two weeks of global protest. the campaign, coordinated by extinction rebellion, is pushing for more urgent government action to stop rising carbon emissions. in london there were more than 250
#
# Summary:
# the campaign, coordinated by extinction rebellion, is pushing for more urgent government action to stop rising carbon emissions.
#
#
# Original Text:
# well, there's two parts of climate change. one is that as the arctic gets warmer there's more water coming off the glasers and sea level
#
# Summary:
#
#
#
# Original Text:
# geithner to safeguard china's assets in the u.s. which total more than $800 billion. the two sides also signed an agreement promising greater cooperation in tackling global warming. that's it from cnbc, first in business worldwide. back to msnbc.
#
# Summary:
# the two sides also signed an agreement promising greater cooperation in tackling global warming.
#
#
# Original Text:
# officially announce her bid for president. she said, my whole life i had only one client, the people. she talked about climate change, sexual assault, the war on drugs and aftermath of the recession and about race in america. and she said this about the current state of the white house.
#
# Summary:
# she talked about climate change, sexual assault, the war on drugs and aftermath of the recession and about race in america.
#
#
# Original Text:
# with climate change comes at a cost. finding the most recent two-year delay has added nearly $4 trillion to the cost of a burning climate catastrophe. right now, we have reached something of a consensus moment on the threat of climate change. scientific establishment, the military establishment, even much of the business
#
# Summary:
# finding the most recent two-year delay has added nearly $4 trillion to the cost of a burning climate catastrophe.
#
#
# Original Text:
# hi, julie. obviously president trump and pope francis had famously clashed over issues like immigration, migration, climate change, but i don't expect we will see anything but smiling faces when they come out of this
#
# Summary:
#
#
#
# Original Text:
# now. general, there are u.s. military officials who say there is a military imperative here, a defense imperative. james mattis said climate change is a big issue. if the president or when perhaps
#
# Summary:
# general, there are u.s. military officials who say there is a military imperative here, a defense imperative.
#
#
# Original Text:
# the secretaries will be giving recommendations to the president shortly but would not say if that meant today. a rock-and-roll star is bragging about snubbing the former president, and a former presidential contender is snubbed on climate change.
#
# Summary:
#
#
#
# Original Text:
# because we have figured out solutions. one of the things that put some more greenhouse gas emissions than anything else is the production of cement. today, in labs, they were going to reveal that there is a new way of actually making cement that will actually capture all
#
# Summary:
#
#
#
# Original Text:
# ambassador wrote canada is committed to additional actions to reduce carbon emissions further. on friday, he told me and president obama, he says if the president says no to the pipeline, he's going to be saying yes to greenhouse gases.
#
# Summary:
#
#
#
# Original Text:
# on climate change. reporter: they signed on to the goal of cutting greenhouse gas emissions by 80% by 2050. today, joined by leaders from rapidly developing countries who are also big polluters like china, india and brazil, they
#
# Summary:
#
#
#
# Original Text:
# news flash. the earth is a planet, not a star. which leads me to ask, if al gore can be wrong about these basic facts, why should anyone trust him about climate change? now, enter sarah palin. in an op-ed piece in 'the
#
# Summary:
# which leads me to ask, if al gore can be wrong about these basic facts, why should anyone trust him about climate change?
#
#
# Original Text:
# to ta ke challenges, then labour would want to take another look at the issue of airport capacity in the south-east and just for good measure he is number two john mcdonald this morning said labour would never be taken seriously on climate change if it pressed ahead with the third ru nway runway and also suggesting that the
#
# Summary:

# %% [markdown]
# ### Summarization using entity recognition

# %%
import spacy
import pandas as pd


# Load spaCy model
nlp = spacy.load("en_core_web_sm")

def summarize_text_with_spacy(text):
    # Process the text with spaCy
    doc = nlp(text)

    # Extract the main subject (entity) from the text
    main_subjects = []
    for ent in doc.ents:
        if ent.label_ in ["ORG", "PERSON", "GPE"]:  # Consider only organizations, people, and geopolitical entities
            main_subjects.append(ent.text)

    # If no named entities are found, use the root of the sentence
    if not main_subjects:
        for sent in doc.sents:
            main_subjects.append(sent.root.text)

    # Return the main subjects as a summarized text
    return ", ".join(main_subjects)

# Apply summarization function to each snippet in the DataFrame
sample_df['summary'] = sample_df['snippet'].apply(summarize_text_with_spacy)

# Display the original snippet and its summary
for index, row in sample_df.iterrows():
    print("Original Text:")
    print(row['snippet'])
    print("\nSummary:")
    print(row['summary'])
    print("\n")
# Out:
# Original Text:
# wrong. i have to go because wayne has agreed with juan in two of the three blocks so far, we're going to have to leave it there. my head is spinning. thanks to michelle fields and juan williams for joining us this week. coming up snowed in and sick of it. hey, global warming crowd, i got
#
# Summary:
# michelle fields, juan williams
#
#
# Original Text:
# and i followed grimm's response to hurricane sandy and traced his trajectory on the issue of climate change and something amazing happened over the course of our time with him. republican michael grimm went from being a climate change denialist, someone who rejected
#
# Summary:
# grimm, michael grimm
#
#
# Original Text:
# that climate change exists than a blizzard that it doesn't. unless a blizzard hits miami. we have a panel of experts to help us understand the science and consequences of climate change and yes, ideas to break the political paralysis over it. kate marvel is a scientist at
#
# Summary:
# miami, kate
#
#
# Original Text:
# it is up on the high plains of the country. as you can see, it is hot and it is dry, and according to the un this whole region is among the most vulnerable to climate change in the world. but the people here have been
#
# Summary:
# un
#
#
# Original Text:
# sense that we are facing a crisis. if you look at the intergovernmental plan on climate change, a report on climate change, it let's us know that we are at a tipping point. that within the decade or so that we are going to experience irreversible tag to the planet. so something has to happen.
#
# Summary:
# sense, let, going, has
#
#
# Original Text:
# of congress, a difficult one. someone should tell her that if you want to be taken seriously even as the youngest member of the house, protesting outside the former speaker's office isn't a genius move. she appeared with 200 young climate change activists and it
#
# Summary:
# congress
#
#
# Original Text:
# opportunity to solve the climate crisis. the world's major powers came within several signatures of endorsing a binding global framework to reduce carbon emissions far closer than we have come since. you go on to write about the conditions of success.
#
# Summary:
# opportunity, came, go
#
#
# Original Text:
# politics of congress. just before i let you go, the lead story, this executive order changing the us policy on climate change affecting the coal and gas embers billy mcclure energies, it is generating a
#
# Summary:
# congress, us
#
#
# Original Text:
# pipeline if it could droibt climate change. something his own state department concluded would not occur, not surprisingly, though, the president sided with his own party. here's what he had to say. america's now a global leader when it comes to taking serious action to fight climate change.
#
# Summary:
# america
#
#
# Original Text:
# for example, in the rest of the world where global warming is a huge issue. a great point. what is the rest of the world saying about the united states? we sit here in denial. our lawmakers do. oh, by the way, what ever happened to cap and trade?
#
# Summary:
# the united states
#
#
# Original Text:
# is disappearing. around 300000 people live around its waters, many make their living by fishing in it. but now dam and irrigation projects in neighbouring ethiopia combined with climate change could see it reduced to a small pool of water. the bbc's nancy kacungira has been
#
# Summary:
# bbc, nancy kacungira
#
#
# Original Text:
# the switch can be both on and off. this supercharges any computer programme, making impossible problems easy to solve. we could find answers to climate change, make rapid progress in artificial intelligence and break encryption - secure codes            _
#
# Summary:
# be, supercharges, find
#
#
# Original Text:
# oppose that idea, though. the conference is in the suburbs of paris. while there, president obama has taken the opportunity to talk not just climate change, but the terrorist attacks that killed 130 people on friday the 13th.
#
# Summary:
# paris
#
#
# Original Text:
# line of the night. it was disingenuine. when he was gofrp vernor, he accepted climate change, he was enlightened on the subject. i think it's another example of the way he has pandered, the way he's changed his views or his
#
# Summary:
# line, was, enlightened, think
#
#
# Original Text:
# senate on record saying climate change is real. it is not a hoax. that measure passed by a 98-1 margin. senators voted down a pair of amendments to the bill saying human activity is part of it.
#
# Summary:
# senate
#
#
# Original Text:
# to think on these issues. very disturbing and parental rights are absolutely left out of the picture. pete: we see it more and more, california is being criticized for allowing transgender issues to be taught in the classroom. right. pete: new york school board wants to climate change
#
# Summary:
# california, new york school board
#
#
# Original Text:
# from companies like royal dutch shell. global investors have asked for commitments to reach carbon neutrality by 2050. altering the course of the climate crisis presents itself
#
# Summary:
# from, asked, presents
#
#
# Original Text:
# pentagon, would you? no, i think that the department of defence was under very strict political supervision from the 0bama white house and that they were told to make sure that climate change is involved in all of your thinking about defence, so no, i do not
#
# Summary:
# pentagon, white house
#
#
# Original Text:
# prop up your only ally, is leadership, then we have got a different definition. leadership. my definition of leadership would be leading on climate change and international accord potential in paris.
#
# Summary:
# paris
#
#
# Original Text:
# will continue to participate in climate change meetings until the withdrawal process is completed. an oxford university employee, who's been on the run on suspicion of murder, has been arrested with his alleged accomplice. andrew warren and professor wyndham
#
# Summary:
# oxford university, andrew warren
#
#
# Original Text:
# billionaire tom stier has pledged $100 million for any lawmaker who is going to make climate change one of his or her campaign processes, campaign ideologies, thoughts going forward. so 96 of them, or whatever, all
#
# Summary:
# tom stier
#
#
# Original Text:
# chance that the scepticism about climate change that we heard from trump in the white house is going to galvanise people want to do more, to ta ke take on more of the button because its not having to limit happening at
#
# Summary:
# the white house
#
#
# Original Text:
# great industrialized nations, and he seems to relate this to be the odd man out on a lot of issues whether it's trade. whether it's iran, whether it's climate change. also now about reassured mitting russia, and i think in fact some
#
# Summary:
# iran, russia
#
#
# Original Text:
# in the antarctic the size of delaware that is detaching. climate change is happening. the physics, mother nature is going to do what she's going to do whether trump stays in the paris climate deal or not and i think they get that this is a
#
# Summary:
# delaware, paris
#
#
# Original Text:
# to an extent. let's not forget this guy has held office in delaware for 30 years, probably shaken every single hand in that state. democrats will probably try to present him as having gone to the right a bit on abortion rights, climate change in his
#
# Summary:
# delaware
#
#
# Original Text:
# this great american experience. exactly. i don't even call climate change tis climate crisis. the old ways are no longer relevant. the scientists tell us we have 12 years before there is irrepairable damage to the
#
# Summary:
# experience, exactly, call, are, tell
#
#
# Original Text:
# and fuel trucks. and cut their greenhouse gas emissions in half. algae. its potential just keeps growing. its potential just keeps growing. performance comes in lots of flavors.  (dramatic orchestra)
#
# Summary:
# trucks, cut, keeps, keeps, comes, orchestra
#
#
# Original Text:
# trade that drives the relationship. when it comes to climate change or getting north korea to contain its nuclear ambitions, america needs china onside. with a closer look at this meeting of the two presidents and really
#
# Summary:
# north korea, america, china
#
#
# Original Text:
# that's stephen colbert breaking down climate change. why is the most liberal city in the nation arresting so many people for smoking pot? that's straight ahead. woman: this is not exactly what i expected. man: definitely more murdery than the reviews said.
#
# Summary:
# 's, is, 's, is, said
#
#
# Original Text:
# democratic voters tell us are the most important. they have climate change as number one. number two, 75% say medicare for all. as a pragmatic idealist, you do not support the version of medicare for all which would
#
# Summary:
# medicare, medicare
#
#
# Original Text:
# epa administrator scott pruitt is forced to resign amid pressure from lawmakers and the sheer embarrassment factor of moments like this one. we deserve to have something about at the epa who does protect our environment, someone who believes in climate change
#
# Summary:
# epa, scott pruitt, epa
#
#
# Original Text:
# all of which made me want to know, are there other approaches and are there other strategies we might pursue? in that spirit and in the wake of the copenhagen spirit here is a fascinating conversation and a fascinating set of ideas, concrete ideas to solve the problem of global warming and
#
# Summary:
# are, is
#
#
# Original Text:
# climate change. it's a threat to our future. to the future of my 7-month-old daughter. that has a lot to do with why i got in the campaign. i want to make her proud and know i did everything i can to
#
# Summary:
# change, 's, to, has, want
#
#
# Original Text:
# he got a state visit. the last time that we had a donald trump state visit it cost £80 million in policing costs and we should not be rolling out the red carpet and spending that kind of money for somebody whose views you have just heard, around climate change and
#
# Summary:
# got, cost
#
#
# Original Text:
# defiance is in our bones. defiance never grows old. citracal maximum. calcium citrate plus d. highly soluble, easily absorbed. climate change has become a partisan issue.
#
# Summary:
# is, grows, maximum, absorbed, become
#
#
# Original Text:
# about donald trump. do you see a trump presidency undoing all the progress that the u.s. has made in the last ten years in the fight against climate change? he has said some things on the climate crisis that i think
#
# Summary:
# donald trump, u.s.
#
#
# Original Text:
# documentary. a controversial one at that, on global warming, after this. you never considered making turn-by-turn navigation standard. if you want to talk about it. call me when you get there. that is if you find there, since you don't have
#
# Summary:
# documentary, one, considered, want, call, is
#
#
# Original Text:
# if they go what he called 'off limits.' thousands of climate change activists have begun two weeks of global protest. the campaign, coordinated by extinction rebellion, is pushing for more urgent government action to stop rising carbon emissions. in london there were more than 250
#
# Summary:
# london
#
#
# Original Text:
# well, there's two parts of climate change. one is that as the arctic gets warmer there's more water coming off the glasers and sea level
#
# Summary:
# 's, is
#
#
# Original Text:
# geithner to safeguard china's assets in the u.s. which total more than $800 billion. the two sides also signed an agreement promising greater cooperation in tackling global warming. that's it from cnbc, first in business worldwide. back to msnbc.
#
# Summary:
# china, u.s., cnbc, msnbc
#
#
# Original Text:
# officially announce her bid for president. she said, my whole life i had only one client, the people. she talked about climate change, sexual assault, the war on drugs and aftermath of the recession and about race in america. and she said this about the current state of the white house.
#
# Summary:
# america, the white house
#
#
# Original Text:
# with climate change comes at a cost. finding the most recent two-year delay has added nearly $4 trillion to the cost of a burning climate catastrophe. right now, we have reached something of a consensus moment on the threat of climate change. scientific establishment, the military establishment, even much of the business
#
# Summary:
# comes, added, reached, establishment
#
#
# Original Text:
# hi, julie. obviously president trump and pope francis had famously clashed over issues like immigration, migration, climate change, but i don't expect we will see anything but smiling faces when they come out of this
#
# Summary:
# pope francis
#
#
# Original Text:
# now. general, there are u.s. military officials who say there is a military imperative here, a defense imperative. james mattis said climate change is a big issue. if the president or when perhaps
#
# Summary:
# u.s., james mattis
#
#
# Original Text:
# the secretaries will be giving recommendations to the president shortly but would not say if that meant today. a rock-and-roll star is bragging about snubbing the former president, and a former presidential contender is snubbed on climate change.
#
# Summary:
# giving, bragging
#
#
# Original Text:
# because we have figured out solutions. one of the things that put some more greenhouse gas emissions than anything else is the production of cement. today, in labs, they were going to reveal that there is a new way of actually making cement that will actually capture all
#
# Summary:
# figured, is, going
#
#
# Original Text:
# ambassador wrote canada is committed to additional actions to reduce carbon emissions further. on friday, he told me and president obama, he says if the president says no to the pipeline, he's going to be saying yes to greenhouse gases.
#
# Summary:
# canada
#
#
# Original Text:
# on climate change. reporter: they signed on to the goal of cutting greenhouse gas emissions by 80% by 2050. today, joined by leaders from rapidly developing countries who are also big polluters like china, india and brazil, they
#
# Summary:
# china, india, brazil
#
#
# Original Text:
# news flash. the earth is a planet, not a star. which leads me to ask, if al gore can be wrong about these basic facts, why should anyone trust him about climate change? now, enter sarah palin. in an op-ed piece in 'the
#
# Summary:
# al gore, sarah palin
#
#
# Original Text:
# to ta ke challenges, then labour would want to take another look at the issue of airport capacity in the south-east and just for good measure he is number two john mcdonald this morning said labour would never be taken seriously on climate change if it pressed ahead with the third ru nway runway and also suggesting that the
#
# Summary:
# john mcdonald

# %% [markdown]
# ### Abstractive summarization

# %%
import spacy
import pandas as pd

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

def summarize_text_without_entities(text):
    # Process the text with spaCy
    doc = nlp(text)

    # Extract the most important words or phrases using dependency parsing
    main_ideas = []
    for sent in doc.sents:
        root = None
        for token in sent:
            if token.dep_ == "ROOT":
                root = token
                break
        if root:
            # Add the root token and its direct children to the main ideas
            main_ideas.append(root.text)
            for child in root.children:
                if child.dep_ != "punct":  # Exclude punctuation
                    main_ideas.append(child.text)

    # Return the main ideas as a summarized text
    return " ".join(main_ideas[:4])  # Limit to 3-4 words

# Apply summarization function to each snippet in the DataFrame
sample_df['summary'] = sample_df['snippet'].apply(summarize_text_without_entities)

# Display the original snippet and its summary
for index, row in sample_df.iterrows():
    print("Original Text:")
    print(row['snippet'])
    print("\nSummary:")
    print(row['summary'])
    print("\n")
# Out:
# Original Text:
# wrong. i have to go because wayne has agreed with juan in two of the three blocks so far, we're going to have to leave it there. my head is spinning. thanks to michelle fields and juan williams for joining us this week. coming up snowed in and sick of it. hey, global warming crowd, i got
#
# Summary:
# wrong have i go
#
#
# Original Text:
# and i followed grimm's response to hurricane sandy and traced his trajectory on the issue of climate change and something amazing happened over the course of our time with him. republican michael grimm went from being a climate change denialist, someone who rejected
#
# Summary:
# followed and i response
#
#
# Original Text:
# that climate change exists than a blizzard that it doesn't. unless a blizzard hits miami. we have a panel of experts to help us understand the science and consequences of climate change and yes, ideas to break the political paralysis over it. kate marvel is a scientist at
#
# Summary:
# exists change than hits
#
#
# Original Text:
# it is up on the high plains of the country. as you can see, it is hot and it is dry, and according to the un this whole region is among the most vulnerable to climate change in the world. but the people here have been
#
# Summary:
# is it up on
#
#
# Original Text:
# sense that we are facing a crisis. if you look at the intergovernmental plan on climate change, a report on climate change, it let's us know that we are at a tipping point. that within the decade or so that we are going to experience irreversible tag to the planet. so something has to happen.
#
# Summary:
# sense facing let look
#
#
# Original Text:
# of congress, a difficult one. someone should tell her that if you want to be taken seriously even as the youngest member of the house, protesting outside the former speaker's office isn't a genius move. she appeared with 200 young climate change activists and it
#
# Summary:
# of congress one .
#
#
# Original Text:
# opportunity to solve the climate crisis. the world's major powers came within several signatures of endorsing a binding global framework to reduce carbon emissions far closer than we have come since. you go on to write about the conditions of success.
#
# Summary:
# opportunity solve came powers
#
#
# Original Text:
# politics of congress. just before i let you go, the lead story, this executive order changing the us policy on climate change affecting the coal and gas embers billy mcclure energies, it is generating a
#
# Summary:
# politics of generating let
#
#
# Original Text:
# pipeline if it could droibt climate change. something his own state department concluded would not occur, not surprisingly, though, the president sided with his own party. here's what he had to say. america's now a global leader when it comes to taking serious action to fight climate change.
#
# Summary:
# pipeline droibt sided something
#
#
# Original Text:
# for example, in the rest of the world where global warming is a huge issue. a great point. what is the rest of the world saying about the united states? we sit here in denial. our lawmakers do. oh, by the way, what ever happened to cap and trade?
#
# Summary:
# for example point a
#
#
# Original Text:
# is disappearing. around 300000 people live around its waters, many make their living by fishing in it. but now dam and irrigation projects in neighbouring ethiopia combined with climate change could see it reduced to a small pool of water. the bbc's nancy kacungira has been
#
# Summary:
# disappearing is make live
#
#
# Original Text:
# the switch can be both on and off. this supercharges any computer programme, making impossible problems easy to solve. we could find answers to climate change, make rapid progress in artificial intelligence and break encryption - secure codes            _
#
# Summary:
# be switch can on
#
#
# Original Text:
# oppose that idea, though. the conference is in the suburbs of paris. while there, president obama has taken the opportunity to talk not just climate change, but the terrorist attacks that killed 130 people on friday the 13th.
#
# Summary:
# oppose idea though is
#
#
# Original Text:
# line of the night. it was disingenuine. when he was gofrp vernor, he accepted climate change, he was enlightened on the subject. i think it's another example of the way he has pandered, the way he's changed his views or his
#
# Summary:
# line of was it
#
#
# Original Text:
# senate on record saying climate change is real. it is not a hoax. that measure passed by a 98-1 margin. senators voted down a pair of amendments to the bill saying human activity is part of it.
#
# Summary:
# is senate change real
#
#
# Original Text:
# to think on these issues. very disturbing and parental rights are absolutely left out of the picture. pete: we see it more and more, california is being criticized for allowing transgender issues to be taught in the classroom. right. pete: new york school board wants to climate change
#
# Summary:
# think to on left
#
#
# Original Text:
# from companies like royal dutch shell. global investors have asked for commitments to reach carbon neutrality by 2050. altering the course of the climate crisis presents itself
#
# Summary:
# from companies asked investors
#
#
# Original Text:
# pentagon, would you? no, i think that the department of defence was under very strict political supervision from the 0bama white house and that they were told to make sure that climate change is involved in all of your thinking about defence, so no, i do not
#
# Summary:
# would pentagon you think
#
#
# Original Text:
# prop up your only ally, is leadership, then we have got a different definition. leadership. my definition of leadership would be leading on climate change and international accord potential in paris.
#
# Summary:
# got prop then we
#
#
# Original Text:
# will continue to participate in climate change meetings until the withdrawal process is completed. an oxford university employee, who's been on the run on suspicion of murder, has been arrested with his alleged accomplice. andrew warren and professor wyndham
#
# Summary:
# continue will participate completed
#
#
# Original Text:
# billionaire tom stier has pledged $100 million for any lawmaker who is going to make climate change one of his or her campaign processes, campaign ideologies, thoughts going forward. so 96 of them, or whatever, all
#
# Summary:
# pledged stier has million
#
#
# Original Text:
# chance that the scepticism about climate change that we heard from trump in the white house is going to galvanise people want to do more, to ta ke take on more of the button because its not having to limit happening at
#
# Summary:
# chance going
#
#
# Original Text:
# great industrialized nations, and he seems to relate this to be the odd man out on a lot of issues whether it's trade. whether it's iran, whether it's climate change. also now about reassured mitting russia, and i think in fact some
#
# Summary:
# nations great industrialized and
#
#
# Original Text:
# in the antarctic the size of delaware that is detaching. climate change is happening. the physics, mother nature is going to do what she's going to do whether trump stays in the paris climate deal or not and i think they get that this is a
#
# Summary:
# size in the of
#
#
# Original Text:
# to an extent. let's not forget this guy has held office in delaware for 30 years, probably shaken every single hand in that state. democrats will probably try to present him as having gone to the right a bit on abortion rights, climate change in his
#
# Summary:
# to extent let forget
#
#
# Original Text:
# this great american experience. exactly. i don't even call climate change tis climate crisis. the old ways are no longer relevant. the scientists tell us we have 12 years before there is irrepairable damage to the
#
# Summary:
# experience this great american
#
#
# Original Text:
# and fuel trucks. and cut their greenhouse gas emissions in half. algae. its potential just keeps growing. its potential just keeps growing. performance comes in lots of flavors.  (dramatic orchestra)
#
# Summary:
# trucks and fuel cut
#
#
# Original Text:
# trade that drives the relationship. when it comes to climate change or getting north korea to contain its nuclear ambitions, america needs china onside. with a closer look at this meeting of the two presidents and really
#
# Summary:
# trade drives needs comes
#
#
# Original Text:
# that's stephen colbert breaking down climate change. why is the most liberal city in the nation arresting so many people for smoking pot? that's straight ahead. woman: this is not exactly what i expected. man: definitely more murdery than the reviews said.
#
# Summary:
# 's that breaking is
#
#
# Original Text:
# democratic voters tell us are the most important. they have climate change as number one. number two, 75% say medicare for all. as a pragmatic idealist, you do not support the version of medicare for all which would
#
# Summary:
# tell voters us are
#
#
# Original Text:
# epa administrator scott pruitt is forced to resign amid pressure from lawmakers and the sheer embarrassment factor of moments like this one. we deserve to have something about at the epa who does protect our environment, someone who believes in climate change
#
# Summary:
# forced pruitt is resign
#
#
# Original Text:
# all of which made me want to know, are there other approaches and are there other strategies we might pursue? in that spirit and in the wake of the copenhagen spirit here is a fascinating conversation and a fascinating set of ideas, concrete ideas to solve the problem of global warming and
#
# Summary:
# are made there approaches
#
#
# Original Text:
# climate change. it's a threat to our future. to the future of my 7-month-old daughter. that has a lot to do with why i got in the campaign. i want to make her proud and know i did everything i can to
#
# Summary:
# change climate 's it
#
#
# Original Text:
# he got a state visit. the last time that we had a donald trump state visit it cost £80 million in policing costs and we should not be rolling out the red carpet and spending that kind of money for somebody whose views you have just heard, around climate change and
#
# Summary:
# got he visit cost
#
#
# Original Text:
# defiance is in our bones. defiance never grows old. citracal maximum. calcium citrate plus d. highly soluble, easily absorbed. climate change has become a partisan issue.
#
# Summary:
# is defiance in grows
#
#
# Original Text:
# about donald trump. do you see a trump presidency undoing all the progress that the u.s. has made in the last ten years in the fight against climate change? he has said some things on the climate crisis that i think
#
# Summary:
# about trump see do
#
#
# Original Text:
# documentary. a controversial one at that, on global warming, after this. you never considered making turn-by-turn navigation standard. if you want to talk about it. call me when you get there. that is if you find there, since you don't have
#
# Summary:
# documentary one a controversial
#
#
# Original Text:
# if they go what he called 'off limits.' thousands of climate change activists have begun two weeks of global protest. the campaign, coordinated by extinction rebellion, is pushing for more urgent government action to stop rising carbon emissions. in london there were more than 250
#
# Summary:
# go if they called
#
#
# Original Text:
# well, there's two parts of climate change. one is that as the arctic gets warmer there's more water coming off the glasers and sea level
#
# Summary:
# 's well there parts
#
#
# Original Text:
# geithner to safeguard china's assets in the u.s. which total more than $800 billion. the two sides also signed an agreement promising greater cooperation in tackling global warming. that's it from cnbc, first in business worldwide. back to msnbc.
#
# Summary:
# geithner safeguard total signed
#
#
# Original Text:
# officially announce her bid for president. she said, my whole life i had only one client, the people. she talked about climate change, sexual assault, the war on drugs and aftermath of the recession and about race in america. and she said this about the current state of the white house.
#
# Summary:
# announce officially bid said
#
#
# Original Text:
# with climate change comes at a cost. finding the most recent two-year delay has added nearly $4 trillion to the cost of a burning climate catastrophe. right now, we have reached something of a consensus moment on the threat of climate change. scientific establishment, the military establishment, even much of the business
#
# Summary:
# comes with change at
#
#
# Original Text:
# hi, julie. obviously president trump and pope francis had famously clashed over issues like immigration, migration, climate change, but i don't expect we will see anything but smiling faces when they come out of this
#
# Summary:
# hi julie clashed trump
#
#
# Original Text:
# now. general, there are u.s. military officials who say there is a military imperative here, a defense imperative. james mattis said climate change is a big issue. if the president or when perhaps
#
# Summary:
# now are general there
#
#
# Original Text:
# the secretaries will be giving recommendations to the president shortly but would not say if that meant today. a rock-and-roll star is bragging about snubbing the former president, and a former presidential contender is snubbed on climate change.
#
# Summary:
# giving secretaries will be
#
#
# Original Text:
# because we have figured out solutions. one of the things that put some more greenhouse gas emissions than anything else is the production of cement. today, in labs, they were going to reveal that there is a new way of actually making cement that will actually capture all
#
# Summary:
# figured because we have
#
#
# Original Text:
# ambassador wrote canada is committed to additional actions to reduce carbon emissions further. on friday, he told me and president obama, he says if the president says no to the pipeline, he's going to be saying yes to greenhouse gases.
#
# Summary:
# wrote ambassador canada is
#
#
# Original Text:
# on climate change. reporter: they signed on to the goal of cutting greenhouse gas emissions by 80% by 2050. today, joined by leaders from rapidly developing countries who are also big polluters like china, india and brazil, they
#
# Summary:
# on change reporter signed
#
#
# Original Text:
# news flash. the earth is a planet, not a star. which leads me to ask, if al gore can be wrong about these basic facts, why should anyone trust him about climate change? now, enter sarah palin. in an op-ed piece in 'the
#
# Summary:
# flash news is earth
#
#
# Original Text:
# to ta ke challenges, then labour would want to take another look at the issue of airport capacity in the south-east and just for good measure he is number two john mcdonald this morning said labour would never be taken seriously on climate change if it pressed ahead with the third ru nway runway and also suggesting that the
#
# Summary:
# want to then labour
